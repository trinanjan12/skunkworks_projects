# %%
#https://medium.com/diving-in-deep/facial-keypoints-detection-with-pytorch-86bac79141e4

# %%
import pandas as pd
from pathlib import Path
from matplotlib import pyplot as plt
import numpy as np

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import torchvision.models as models

# %%
data_dir = Path('./Facial_Keypoints_Detection_Kaggle')
train_data = pd.read_csv(data_dir/'training.csv')
train_data.T
# Out:
#                                                                         0     \
# left_eye_center_x                                                    66.0336
# left_eye_center_y                                                    39.0023
# right_eye_center_x                                                    30.227
# right_eye_center_y                                                   36.4217
# left_eye_inner_corner_x                                              59.5821
# left_eye_inner_corner_y                                              39.6474
# left_eye_outer_corner_x                                              73.1303
# left_eye_outer_corner_y                                                39.97
# right_eye_inner_corner_x                                             36.3566
# right_eye_inner_corner_y                                             37.3894
# right_eye_outer_corner_x                                             23.4529
# right_eye_outer_corner_y                                             37.3894
# left_eyebrow_inner_end_x                                             56.9533
# left_eyebrow_inner_end_y                                             29.0336
# left_eyebrow_outer_end_x                                             80.2271
# left_eyebrow_outer_end_y                                             32.2281
# right_eyebrow_inner_end_x                                            40.2276
# right_eyebrow_inner_end_y                                            29.0023
# right_eyebrow_outer_end_x                                            16.3564
# right_eyebrow_outer_end_y                                            29.6475
# nose_tip_x                                                           44.4206
# nose_tip_y                                                           57.0668
# mouth_left_corner_x                                                  61.1953
# mouth_left_corner_y                                                  79.9702
# mouth_right_corner_x                                                 28.6145
# mouth_right_corner_y                                                  77.389
# mouth_center_top_lip_x                                               43.3126
# mouth_center_top_lip_y                                               72.9355
# mouth_center_bottom_lip_x                                            43.1307
# mouth_center_bottom_lip_y                                            84.4858
# Image                      238 236 237 238 240 240 239 241 241 243 240 23...
#
#                                                                         1     \
# left_eye_center_x                                                    64.3329
# left_eye_center_y                                                    34.9701
# right_eye_center_x                                                   29.9493
# right_eye_center_y                                                   33.4487
# left_eye_inner_corner_x                                              58.8562
# left_eye_inner_corner_y                                              35.2743
# left_eye_outer_corner_x                                              70.7227
# left_eye_outer_corner_y                                              36.1872
# right_eye_inner_corner_x                                             36.0347
# right_eye_inner_corner_y                                             34.3615
# right_eye_outer_corner_x                                             24.4725
# right_eye_outer_corner_y                                             33.1444
# left_eyebrow_inner_end_x                                             53.9874
# left_eyebrow_inner_end_y                                             28.2759
# left_eyebrow_outer_end_x                                             78.6342
# left_eyebrow_outer_end_y                                             30.4059
# right_eyebrow_inner_end_x                                            42.7289
# right_eyebrow_inner_end_y                                             26.146
# right_eyebrow_outer_end_x                                            16.8654
# right_eyebrow_outer_end_y                                            27.0589
# nose_tip_x                                                           48.2063
# nose_tip_y                                                           55.6609
# mouth_left_corner_x                                                  56.4214
# mouth_left_corner_y                                                   76.352
# mouth_right_corner_x                                                 35.1224
# mouth_right_corner_y                                                 76.0477
# mouth_center_top_lip_x                                               46.6846
# mouth_center_top_lip_y                                               70.2666
# mouth_center_bottom_lip_x                                            45.4679
# mouth_center_bottom_lip_y                                            85.4802
# Image                      219 215 204 196 204 211 212 200 180 168 178 19...
#
#                                                                         2     \
# left_eye_center_x                                                    65.0571
# left_eye_center_y                                                    34.9096
# right_eye_center_x                                                   30.9038
# right_eye_center_y                                                   34.9096
# left_eye_inner_corner_x                                               59.412
# left_eye_inner_corner_y                                               36.321
# left_eye_outer_corner_x                                              70.9844
# left_eye_outer_corner_y                                               36.321
# right_eye_inner_corner_x                                             37.6781
# right_eye_inner_corner_y                                              36.321
# right_eye_outer_corner_x                                             24.9764
# right_eye_outer_corner_y                                             36.6032
# left_eyebrow_inner_end_x                                             55.7425
# left_eyebrow_inner_end_y                                             27.5709
# left_eyebrow_outer_end_x                                             78.8874
# left_eyebrow_outer_end_y                                             32.6516
# right_eyebrow_inner_end_x                                            42.1939
# right_eyebrow_inner_end_y                                            28.1355
# right_eyebrow_outer_end_x                                            16.7912
# right_eyebrow_outer_end_y                                            32.0871
# nose_tip_x                                                           47.5573
# nose_tip_y                                                           53.5389
# mouth_left_corner_x                                                  60.8229
# mouth_left_corner_y                                                  73.0143
# mouth_right_corner_x                                                 33.7263
# mouth_right_corner_y                                                  72.732
# mouth_center_top_lip_x                                               47.2749
# mouth_center_top_lip_y                                               70.1918
# mouth_center_bottom_lip_x                                            47.2749
# mouth_center_bottom_lip_y                                            78.6594
# Image                      144 142 159 180 188 188 184 180 167 132 84 59 ...
#
#                                                                         3     \
# left_eye_center_x                                                    65.2257
# left_eye_center_y                                                    37.2618
# right_eye_center_x                                                   32.0231
# right_eye_center_y                                                   37.2618
# left_eye_inner_corner_x                                              60.0033
# left_eye_inner_corner_y                                              39.1272
# left_eye_outer_corner_x                                              72.3147
# left_eye_outer_corner_y                                               38.381
# right_eye_inner_corner_x                                             37.6186
# right_eye_inner_corner_y                                             38.7541
# right_eye_outer_corner_x                                             25.3073
# right_eye_outer_corner_y                                             38.0079
# left_eyebrow_inner_end_x                                             56.4338
# left_eyebrow_inner_end_y                                             30.9299
# left_eyebrow_outer_end_x                                             77.9103
# left_eyebrow_outer_end_y                                             31.6657
# right_eyebrow_inner_end_x                                            41.6715
# right_eyebrow_inner_end_y                                              31.05
# right_eyebrow_outer_end_x                                             20.458
# right_eyebrow_outer_end_y                                            29.9093
# nose_tip_x                                                           51.8851
# nose_tip_y                                                           54.1665
# mouth_left_corner_x                                                  65.5989
# mouth_left_corner_y                                                  72.7037
# mouth_right_corner_x                                                 37.2455
# mouth_right_corner_y                                                 74.1955
# mouth_center_top_lip_x                                               50.3032
# mouth_center_top_lip_y                                               70.0917
# mouth_center_bottom_lip_x                                            51.5612
# mouth_center_bottom_lip_y                                            78.2684
# Image                      193 192 193 194 194 194 193 192 168 111 50 12 ...
#
#                                                                         4     \
# left_eye_center_x                                                    66.7253
# left_eye_center_y                                                    39.6213
# right_eye_center_x                                                   32.2448
# right_eye_center_y                                                    38.042
# left_eye_inner_corner_x                                              58.5659
# left_eye_inner_corner_y                                              39.6213
# left_eye_outer_corner_x                                              72.5159
# left_eye_outer_corner_y                                              39.8845
# right_eye_inner_corner_x                                             36.9824
# right_eye_inner_corner_y                                             39.0949
# right_eye_outer_corner_x                                             22.5061
# right_eye_outer_corner_y                                             38.3052
# left_eyebrow_inner_end_x                                             57.2496
# left_eyebrow_inner_end_y                                             30.6722
# left_eyebrow_outer_end_x                                             77.7629
# left_eyebrow_outer_end_y                                             31.7372
# right_eyebrow_inner_end_x                                            38.0354
# right_eyebrow_inner_end_y                                            30.9354
# right_eyebrow_outer_end_x                                            15.9259
# right_eyebrow_outer_end_y                                            30.6722
# nose_tip_x                                                           43.2995
# nose_tip_y                                                           64.8895
# mouth_left_corner_x                                                  60.6714
# mouth_left_corner_y                                                  77.5232
# mouth_right_corner_x                                                 31.1918
# mouth_right_corner_y                                                 76.9973
# mouth_center_top_lip_x                                               44.9627
# mouth_center_top_lip_y                                               73.7074
# mouth_center_bottom_lip_x                                            44.2271
# mouth_center_bottom_lip_y                                            86.8712
# Image                      147 148 160 196 215 214 216 217 219 220 206 18...
#
#                                                                         5     \
# left_eye_center_x                                                    69.6807
# left_eye_center_y                                                    39.9687
# right_eye_center_x                                                   29.1836
# right_eye_center_y                                                   37.5634
# left_eye_inner_corner_x                                              62.8643
# left_eye_inner_corner_y                                              40.1693
# left_eye_outer_corner_x                                              76.8982
# left_eye_outer_corner_y                                              41.1719
# right_eye_inner_corner_x                                              36.401
# right_eye_inner_corner_y                                             39.3676
# right_eye_outer_corner_x                                             21.7655
# right_eye_outer_corner_y                                             38.5655
# left_eyebrow_inner_end_x                                             59.7663
# left_eyebrow_inner_end_y                                             31.6513
# left_eyebrow_outer_end_x                                             83.3136
# left_eyebrow_outer_end_y                                             35.3581
# right_eyebrow_inner_end_x                                             39.408
# right_eyebrow_inner_end_y                                            30.5464
# right_eyebrow_outer_end_x                                            14.9491
# right_eyebrow_outer_end_y                                            32.1501
# nose_tip_x                                                           52.4685
# nose_tip_y                                                              58.8
# mouth_left_corner_x                                                  64.8691
# mouth_left_corner_y                                                  82.4712
# mouth_right_corner_x                                                 31.9904
# mouth_right_corner_y                                                 81.6691
# mouth_center_top_lip_x                                               49.3081
# mouth_center_top_lip_y                                               78.4876
# mouth_center_bottom_lip_x                                            49.4324
# mouth_center_bottom_lip_y                                            93.8988
# Image                      167 169 170 167 156 145 106 68 52 24 20 15 21 ...
#
#                                                                         6     \
# left_eye_center_x                                                    64.1319
# left_eye_center_y                                                      34.29
# right_eye_center_x                                                    29.579
# right_eye_center_y                                                    33.138
# left_eye_inner_corner_x                                              57.7972
# left_eye_inner_corner_y                                               35.154
# left_eye_outer_corner_x                                              69.0266
# left_eye_outer_corner_y                                                34.29
# right_eye_inner_corner_x                                             34.7617
# right_eye_inner_corner_y                                              33.714
# right_eye_outer_corner_x                                             24.1082
# right_eye_outer_corner_y                                              33.138
# left_eyebrow_inner_end_x                                             58.6612
# left_eyebrow_inner_end_y                                             27.0913
# left_eyebrow_outer_end_x                                             76.2253
# left_eyebrow_outer_end_y                                             29.1073
# right_eyebrow_inner_end_x                                             40.233
# right_eyebrow_inner_end_y                                            27.0913
# right_eyebrow_outer_end_x                                            19.5009
# right_eyebrow_outer_end_y                                            27.6673
# nose_tip_x                                                           46.8551
# nose_tip_y                                                           53.0062
# mouth_left_corner_x                                                  55.7818
# mouth_left_corner_y                                                   70.571
# mouth_right_corner_x                                                 33.8983
# mouth_right_corner_y                                                  70.283
# mouth_center_top_lip_x                                               45.1277
# mouth_center_top_lip_y                                               65.0996
# mouth_center_bottom_lip_x                                            45.4157
# mouth_center_bottom_lip_y                                             78.057
# Image                      109 109 125 141 145 139 120 81 45 34 31 35 36 ...
#
#                                                                         7     \
# left_eye_center_x                                                    67.4689
# left_eye_center_y                                                    39.4135
# right_eye_center_x                                                    29.356
# right_eye_center_y                                                   39.6217
# left_eye_inner_corner_x                                               59.555
# left_eye_inner_corner_y                                              40.4548
# left_eye_outer_corner_x                                              75.5916
# left_eye_outer_corner_y                                              40.0382
# right_eye_inner_corner_x                                             37.4782
# right_eye_inner_corner_y                                             40.4548
# right_eye_outer_corner_x                                             21.0254
# right_eye_outer_corner_y                                             40.0382
# left_eyebrow_inner_end_x                                             56.0141
# left_eyebrow_inner_end_y                                             27.3339
# left_eyebrow_outer_end_x                                             84.1305
# left_eyebrow_outer_end_y                                              31.291
# right_eyebrow_inner_end_x                                            39.7692
# right_eyebrow_inner_end_y                                            26.9174
# right_eyebrow_outer_end_x                                            11.8616
# right_eyebrow_outer_end_y                                            31.9158
# nose_tip_x                                                           47.8919
# nose_tip_y                                                            56.908
# mouth_left_corner_x                                                   66.844
# mouth_left_corner_y                                                  80.0258
# mouth_right_corner_x                                                 30.1892
# mouth_right_corner_y                                                 81.2752
# mouth_center_top_lip_x                                               48.1002
# mouth_center_top_lip_y                                               71.2786
# mouth_center_bottom_lip_x                                            48.5168
# mouth_center_bottom_lip_y                                            91.0639
# Image                      178 177 178 179 179 179 181 185 188 184 192 20...
#
#                                                                         8     \
# left_eye_center_x                                                    65.8029
# left_eye_center_y                                                    34.7552
# right_eye_center_x                                                   27.4758
# right_eye_center_y                                                   36.1856
# left_eye_inner_corner_x                                              58.6522
# left_eye_inner_corner_y                                              37.3293
# left_eye_outer_corner_x                                               72.953
# left_eye_outer_corner_y                                              35.8995
# right_eye_inner_corner_x                                             36.3424
# right_eye_inner_corner_y                                             37.0432
# right_eye_outer_corner_x                                             20.3251
# right_eye_outer_corner_y                                             37.6154
# left_eyebrow_inner_end_x                                             57.5078
# left_eyebrow_inner_end_y                                             25.0304
# left_eyebrow_outer_end_x                                             79.2736
# left_eyebrow_outer_end_y                                             28.6342
# right_eyebrow_inner_end_x                                            36.3424
# right_eyebrow_inner_end_y                                            26.1747
# right_eyebrow_outer_end_x                                             12.889
# right_eyebrow_outer_end_y                                            31.3229
# nose_tip_x                                                           48.0698
# nose_tip_y                                                           55.3485
# mouth_left_corner_x                                                  65.5168
# mouth_left_corner_y                                                  73.3683
# mouth_right_corner_x                                                 31.1942
# mouth_right_corner_y                                                 74.7981
# mouth_center_top_lip_x                                               49.2134
# mouth_center_top_lip_y                                                67.648
# mouth_center_bottom_lip_x                                            49.4995
# mouth_center_bottom_lip_y                                            83.0931
# Image                      164 158 118 76 66 69 59 53 43 31 35 41 45 55 6...
#
#                                                                         9     \
# left_eye_center_x                                                    64.1212
# left_eye_center_y                                                    36.7403
# right_eye_center_x                                                   29.4689
# right_eye_center_y                                                   38.3902
# left_eye_inner_corner_x                                              58.6209
# left_eye_inner_corner_y                                              37.8406
# left_eye_outer_corner_x                                               71.272
# left_eye_outer_corner_y                                              37.2903
# right_eye_inner_corner_x                                             36.3446
# right_eye_inner_corner_y                                             39.4905
# right_eye_outer_corner_x                                             22.8683
# right_eye_outer_corner_y                                             40.0406
# left_eyebrow_inner_end_x                                             56.9711
# left_eyebrow_inner_end_y                                             28.4897
# left_eyebrow_outer_end_x                                             75.9471
# left_eyebrow_outer_end_y                                             29.5898
# right_eyebrow_inner_end_x                                            36.6191
# right_eyebrow_inner_end_y                                            29.3148
# right_eyebrow_outer_end_x                                            16.8178
# right_eyebrow_outer_end_y                                            33.9902
# nose_tip_x                                                           48.9951
# nose_tip_y                                                           54.3415
# mouth_left_corner_x                                                  65.7717
# mouth_left_corner_y                                                  69.1926
# mouth_right_corner_x                                                 32.7692
# mouth_right_corner_y                                                 72.2178
# mouth_center_top_lip_x                                               49.2702
# mouth_center_top_lip_y                                               67.5428
# mouth_center_bottom_lip_x                                            49.5452
# mouth_center_bottom_lip_y                                            76.8935
# Image                      226 227 225 224 221 220 215 210 210 208 206 18...
#
#                            ...  \
# left_eye_center_x          ...
# left_eye_center_y          ...
# right_eye_center_x         ...
# right_eye_center_y         ...
# left_eye_inner_corner_x    ...
# left_eye_inner_corner_y    ...
# left_eye_outer_corner_x    ...
# left_eye_outer_corner_y    ...
# right_eye_inner_corner_x   ...
# right_eye_inner_corner_y   ...
# right_eye_outer_corner_x   ...
# right_eye_outer_corner_y   ...
# left_eyebrow_inner_end_x   ...
# left_eyebrow_inner_end_y   ...
# left_eyebrow_outer_end_x   ...
# left_eyebrow_outer_end_y   ...
# right_eyebrow_inner_end_x  ...
# right_eyebrow_inner_end_y  ...
# right_eyebrow_outer_end_x  ...
# right_eyebrow_outer_end_y  ...
# nose_tip_x                 ...
# nose_tip_y                 ...
# mouth_left_corner_x        ...
# mouth_left_corner_y        ...
# mouth_right_corner_x       ...
# mouth_right_corner_y       ...
# mouth_center_top_lip_x     ...
# mouth_center_top_lip_y     ...
# mouth_center_bottom_lip_x  ...
# mouth_center_bottom_lip_y  ...
# Image                      ...
#
#                                                                         7039  \
# left_eye_center_x                                                    69.2299
# left_eye_center_y                                                    38.5756
# right_eye_center_x                                                   29.4079
# right_eye_center_y                                                   38.3455
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                            49.434
# nose_tip_y                                                           70.8015
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            50.1245
# mouth_center_bottom_lip_y                                            80.2391
# Image                      43 49 57 67 81 98 97 94 91 94 97 101 96 91 88 ...
#
#                                                                         7040  \
# left_eye_center_x                                                     63.353
# left_eye_center_y                                                    35.6713
# right_eye_center_x                                                   33.9521
# right_eye_center_y                                                   40.8164
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                           48.1625
# nose_tip_y                                                            59.682
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            50.3676
# mouth_center_bottom_lip_y                                            70.9523
# Image                      139 140 143 141 141 140 140 139 140 141 143 14...
#
#                                                                         7041  \
# left_eye_center_x                                                    65.7112
# left_eye_center_y                                                    38.8435
# right_eye_center_x                                                   32.2688
# right_eye_center_y                                                    37.706
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                           46.3737
# nose_tip_y                                                            64.096
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            49.7862
# mouth_center_bottom_lip_y                                            78.2009
# Image                      164 165 167 168 169 170 172 171 170 171 173 16...
#
#                                                                         7042  \
# left_eye_center_x                                                    67.9293
# left_eye_center_y                                                    35.8466
# right_eye_center_x                                                   28.6878
# right_eye_center_y                                                   41.4525
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                           50.8446
# nose_tip_y                                                           69.7491
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            52.4463
# mouth_center_bottom_lip_y                                            81.2278
# Image                      254 235 191 141 106 93 94 123 168 178 178 186 ...
#
#                                                                         7043  \
# left_eye_center_x                                                    66.8672
# left_eye_center_y                                                    37.3569
# right_eye_center_x                                                   30.7509
# right_eye_center_y                                                   40.1157
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                           43.5421
# nose_tip_y                                                           64.9457
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                             47.555
# mouth_center_bottom_lip_y                                            79.4926
# Image                      150 150 132 63 44 74 86 61 62 57 44 70 93 115 ...
#
#                                                                         7044  \
# left_eye_center_x                                                    67.4025
# left_eye_center_y                                                    31.8426
# right_eye_center_x                                                   29.7467
# right_eye_center_y                                                   38.6329
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                            48.266
# nose_tip_y                                                           67.0291
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            50.4266
# mouth_center_bottom_lip_y                                            79.6839
# Image                      71 74 85 105 116 128 139 150 170 187 201 209 2...
#
#                                                                         7045  \
# left_eye_center_x                                                    66.1344
# left_eye_center_y                                                    38.3655
# right_eye_center_x                                                   30.4786
# right_eye_center_y                                                   39.9502
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                           47.9103
# nose_tip_y                                                            66.626
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            50.2874
# mouth_center_bottom_lip_y                                             77.983
# Image                      60 60 62 57 55 51 49 48 50 53 56 56 106 89 77 ...
#
#                                                                         7046  \
# left_eye_center_x                                                    66.6907
# left_eye_center_y                                                    36.8452
# right_eye_center_x                                                   31.6664
# right_eye_center_y                                                    39.685
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                           49.4626
# nose_tip_y                                                           67.5152
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            49.4626
# mouth_center_bottom_lip_y                                            78.1171
# Image                      74 74 74 78 79 79 79 81 77 78 80 73 72 81 77 1...
#
#                                                                         7047  \
# left_eye_center_x                                                    70.9651
# left_eye_center_y                                                    39.8537
# right_eye_center_x                                                   30.5433
# right_eye_center_y                                                   40.7723
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                           50.7542
# nose_tip_y                                                            66.725
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            50.0652
# mouth_center_bottom_lip_y                                            79.5864
# Image                      254 254 254 254 254 238 193 145 121 118 119 10...
#
#                                                                         7048
# left_eye_center_x                                                    66.9383
# left_eye_center_y                                                    43.4245
# right_eye_center_x                                                   31.0961
# right_eye_center_y                                                   39.5286
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                           47.0693
# nose_tip_y                                                           73.0333
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            45.9005
# mouth_center_bottom_lip_y                                            82.7731
# Image                      53 62 67 76 86 91 97 105 105 106 107 108 112 1...
#
# [31 rows x 7049 columns]

# %%
IMG_SIZE = 96 # image size 96 x 96 pixels

def show_keypoints(image, keypoints):
    '''
    Show image with keypoints
    Args:
        image (array-like or PIL image): The image data. (M, N)
        keypoints (array-like): The keypoits data. (N, 2)
    '''
      
    plt.imshow(image, cmap='gray')
    if len(keypoints):
        plt.scatter(keypoints[:, 0], keypoints[:, 1], s=24, marker ='.', c='r')
        
def show_images(df, indxs, ncols=5, figsize=(15,10), with_keypoints=True):
    '''
    Show images with keypoints in grids
    Args:
        df (DataFrame): data (M x N)
        idxs (iterators): list, Range, Indexes
        ncols (integer): number of columns (images by rows)
        figsize (float, float): width, height in inches
        with_keypoints (boolean): True if show image with keypoints
    '''
    plt.figure(figsize=figsize)
    nrows = len(indxs) // ncols + 1
    for i, idx in enumerate(indxs):
        image = np.fromstring(df.loc[idx, 'Image'], sep=' ').astype(np.float32)\
                .reshape(-1, IMG_SIZE)
        if with_keypoints:
            keypoints = df.loc[idx].drop('Image').values.astype(np.float32)\
                        .reshape(-1, 2)
        else:
            keypoints = []
        plt.subplot(nrows, ncols, i + 1)
        plt.title(f'Sample #{idx}')
        plt.axis('off')
        plt.tight_layout()
        show_keypoints(image, keypoints)
    plt.show()

# %%
show_images(train_data, range(4))

# %%
missing_any_data = train_data[train_data.isnull().any(axis=1)]
idxs = np.random.choice(missing_any_data.index, 4)
show_images(train_data, idxs)

# %%
test_data = pd.read_csv(data_dir / 'test.csv')
test_data.head()
# Out:
#    ImageId                                              Image
# 0        1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2        3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3        4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...

# %%
train_df = train_data.dropna()
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2140 entries, 0 to 2283
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   left_eye_center_x          2140 non-null   float64
#  1   left_eye_center_y          2140 non-null   float64
#  2   right_eye_center_x         2140 non-null   float64
#  3   right_eye_center_y         2140 non-null   float64
#  4   left_eye_inner_corner_x    2140 non-null   float64
#  5   left_eye_inner_corner_y    2140 non-null   float64
#  6   left_eye_outer_corner_x    2140 non-null   float64
#  7   left_eye_outer_corner_y    2140 non-null   float64
#  8   right_eye_inner_corner_x   2140 non-null   float64
#  9   right_eye_inner_corner_y   2140 non-null   float64
#  10  right_eye_outer_corner_x   2140 non-null   float64
#  11  right_eye_outer_corner_y   2140 non-null   float64
#  12  left_eyebrow_inner_end_x   2140 non-null   float64
#  13  left_eyebrow_inner_end_y   2140 non-null   float64
#  14  left_eyebrow_outer_end_x   2140 non-null   float64
#  15  left_eyebrow_outer_end_y   2140 non-null   float64
#  16  right_eyebrow_inner_end_x  2140 non-null   float64
#  17  right_eyebrow_inner_end_y  2140 non-null   float64
#  18  right_eyebrow_outer_end_x  2140 non-null   float64
#  19  right_eyebrow_outer_end_y  2140 non-null   float64
#  20  nose_tip_x                 2140 non-null   float64
#  21  nose_tip_y                 2140 non-null   float64
#  22  mouth_left_corner_x        2140 non-null   float64
#  23  mouth_left_corner_y        2140 non-null   float64
#  24  mouth_right_corner_x       2140 non-null   float64
#  25  mouth_right_corner_y       2140 non-null   float64
#  26  mouth_center_top_lip_x     2140 non-null   float64
#  27  mouth_center_top_lip_y     2140 non-null   float64
#  28  mouth_center_bottom_lip_x  2140 non-null   float64
#  29  mouth_center_bottom_lip_y  2140 non-null   float64
#  30  Image                      2140 non-null   object
# dtypes: float64(30), object(1)
# memory usage: 535.0+ KB

# %%
class FaceKeypointsDataset(Dataset):
    '''Face Keypoints Dataset'''
    def __init__(self, dataframe, train=True, transform=None):
        '''
        Args:
            dataframe (DataFrame): data in pandas dataframe format.
            train (Boolean) : True for train data with keypoints, default is True
            transform (callable, optional): Optional transform to be applied on 
            sample
        '''
        self.dataframe = dataframe
        self.train = train
        self.transform = transform
    
    def __len__(self):
        return len(self.dataframe)
    
    def __getitem__(self, idx):
        image = np.fromstring(self.dataframe.iloc[idx, -1], sep=' ')\
                .astype(np.float32).reshape(-1, IMG_SIZE)
        if self.train:
            keypoints = self.dataframe.iloc[idx, :-1].values.astype(np.float32)
        else:
            keypoints = None
        sample = {'image': image, 'keypoints': keypoints}
        if self.transform:
            sample = self.transform(sample)
        return sample
    

class Normalize(object):
    '''Normalize input images'''
    def __call__(self, sample):
        image, keypoints = sample['image'], sample['keypoints']
        return {'image': image / 255., # scale to [0, 1]
                'keypoints': keypoints}
        
class ToTensor(object):
    '''Convert ndarrays in sample to Tensors.'''
    def __call__(self, sample):
        image, keypoints = sample['image'], sample['keypoints']
        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.reshape(1, IMG_SIZE, IMG_SIZE)
        image = torch.from_numpy(image)
        if keypoints is not None:
            keypoints = torch.from_numpy(keypoints)
            return {'image': image, 'keypoints': keypoints}
        else:
            return {'image': image}
        
class RandomHorizontalFlip(object):
    '''
    Horizontally flip image randomly with given probability
    Args:
        p (float): probability of the image being flipped.
                   Defalut value = 0.5
    '''
    def __init__(self, p=0.5):
        self.p = p

    def __call__(self, sample):
        
        flip_indices = [(0, 2), (1, 3),
                        (4, 8), (5, 9), (6, 10), (7, 11),
                        (12, 16), (13, 17), (14, 18), (15, 19),
                        (22, 24), (23, 25)]
        image, keypoints = sample['image'], sample['keypoints']
        if np.random.random() < self.p:
            image = image[:, ::-1]
            if keypoints is not None:
                for a, b in flip_iimport torch.nn as nn
from torch import optim
import torch.nn.functional as Fndices:
                    keypoints[a], keypoints[b]= keypoints[b], keypoints[a]
                keypoints[::2] = 96. - keypoints[::2]
        return {'image': image, 
                'keypoints': keypoints}

# %%
from torch.utils.data.sampler import SubsetRandomSampler

def prepare_train_valid_loaders(trainset, valid_size=0.2, 
                                batch_size=128):
    '''
    Split trainset data and prepare DataLoader for training and validation
    
    Args:
        trainset (Dataset): data 
        valid_size (float): validation size, defalut=0.2
        batch_size (int) : batch size, default=128
    ''' 
    
    # obtain training indices that will be used for validation
    num_train = len(trainset)
    indices = import torch.nn as nn
from torch import optim
import torch.nn.functional as Flist(range(num_train))
    np.random.shuffle(indices)
    split = int(np.floor(valid_size * num_train))
    train_idx, valid_idx = indices[split:], indices[:split]
    
    # define samplers for obtaining training and validation batches
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)
    
    # prepare data loaders
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                               sampler=train_sampler)
    valid_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                               sampler=valid_sampler)
    
    return train_loader, valid_loader

# %%
from torchvision import transforms

# drop any-missing-keypoint records
train_df = train_data.dropna()
test_df = test_data

# how many samples per batch to load
batch_size = 128
# percentage of training set to use as validation
valid_size = 0.2

# Define a transform to normalize the data
tsfm = transforms.Compose([RandomHorizontalFlip(p=0.5), Normalize(), ToTensor()])

# Load the training data and test data
trainset = FaceKeypointsDataset(train_df, transform=tsfm)
testset = FaceKeypointsDataset(test_df, train=False, transform=tsfm)

# prepare data loaders
train_loader, valid_loader = prepare_train_valid_loaders(trainset, 
                                                         valid_size,
                                                         batch_size)

test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size)

# %%
class CNN(nn.Module):
    '''
    Convolutional Neural Network model
            
    Args:
        ---------
        output_size (integer): size of the output layer
    '''
    
    def __init__(self, outputs=30):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, 3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64*12*12, 1024)
        self.fc2 = nn.Linear(1024, outputs)
        self.dropout = nn.Dropout(0.3)
        
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 64*12*12)
        x = F.relu(self.fc1(self.dropout(x)))
        x = self.fc2(self.dropout(x))
        
        return x

# %%
def train(train_loader, valid_loader, model, criterion, optimizer, 
          n_epochs=50, saved_model='model.pt'):
    '''
    Train the model
    
    Args:
        train_loader (DataLoader): DataLoader for train Dataset
        valid_loader (DataLoader): DataLoader for valid Dataset
        model (nn.Module): model to be trained on
        criterion (torch.nn): loss funtion
        optimizer (torch.optim): optimization algorithms
        n_epochs (int): number of epochs to train the model
        saved_model (str): file path for saving model
    
    Return:
        tuple of train_losses, valid_losses
    '''

    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf # set initial "min" to infinity

    train_losses = []
    valid_losses = []

    for epoch in range(n_epochs):
        # monitor training loss
        train_loss = 0.0
        valid_loss = 0.0

        ###################
        # train the model #
        ###################
        model.train() # prep model for training
        for batch in train_loader:
            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(batch['image'].to(device))
            # calculate the loss
            loss = criterion(output, batch['keypoints'].to(device))
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update running training loss
            train_loss += loss.item()*batch['image'].size(0)

        ######################    
        # validate the model #
        ######################
        model.eval() # prep model for evaluation
        for batch in valid_loader:
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(batch['image'].to(device))
            # calculate the loss
            loss = criterion(output, batch['keypoints'].to(device))
            # update running validation loss 
            valid_loss += loss.item()*batch['image'].size(0)

        # print training/validation statistics 
        # calculate average Root Mean Square loss over an epoch
        train_loss = np.sqrt(train_loss/len(train_loader.sampler.indices))
        valid_loss = np.sqrt(valid_loss/len(valid_loader.sampler.indices))

        train_losses.append(train_loss)
        valid_losses.append(valid_loss)

        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'
              .format(epoch+1, train_loss, valid_loss))

        # save model if validation loss has decreased
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'
                  .format(valid_loss_min, valid_loss))
            torch.save(model.state_dict(), saved_model)
            valid_loss_min = valid_loss
            
    return train_losses, valid_losses

# %%
model = CNN(outputs=30)
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model = model.to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

# %%
train(train_loader, valid_loader, model, criterion,  
optimizer, n_epochs=50, saved_model='aug_cnn.pt')
# Out:
# Epoch: 1 	Training Loss: 24.593333 	Validation Loss: 8.722365
# Validation loss decreased (inf --> 8.722365).  Saving model ...
# Epoch: 2 	Training Loss: 7.498123 	Validation Loss: 5.215322
# Validation loss decreased (8.722365 --> 5.215322).  Saving model ...
# Epoch: 3 	Training Loss: 5.019913 	Validation Loss: 3.783719
# Validation loss decreased (5.215322 --> 3.783719).  Saving model ...
# Epoch: 4 	Training Loss: 4.158746 	Validation Loss: 3.515807
# Validation loss decreased (3.783719 --> 3.515807).  Saving model ...
# Epoch: 5 	Training Loss: 4.053044 	Validation Loss: 3.730839
# Epoch: 6 	Training Loss: 4.188015 	Validation Loss: 3.771712
# Epoch: 7 	Training Loss: 4.157804 	Validation Loss: 3.487388
# Validation loss decreased (3.515807 --> 3.487388).  Saving model ...
# Epoch: 8 	Training Loss: 3.913416 	Validation Loss: 3.405463
# Validation loss decreased (3.487388 --> 3.405463).  Saving model ...
# Epoch: 9 	Training Loss: 3.863379 	Validation Loss: 3.268291
# Validation loss decreased (3.405463 --> 3.268291).  Saving model ...
# Epoch: 10 	Training Loss: 3.858325 	Validation Loss: 3.582804
# Epoch: 11 	Training Loss: 3.856656 	Validation Loss: 3.507438
# Epoch: 12 	Training Loss: 3.826137 	Validation Loss: 3.242985
# Validation loss decreased (3.268291 --> 3.242985).  Saving model ...
# Epoch: 13 	Training Loss: 3.838132 	Validation Loss: 3.654377
# Epoch: 14 	Training Loss: 3.944439 	Validation Loss: 3.274384
# Epoch: 15 	Training Loss: 3.754912 	Validation Loss: 3.257223
# Epoch: 16 	Training Loss: 3.725608 	Validation Loss: 3.243712
# Epoch: 17 	Training Loss: 3.701744 	Validation Loss: 3.164662
# Validation loss decreased (3.242985 --> 3.164662).  Saving model ...
# Epoch: 18 	Training Loss: 3.735458 	Validation Loss: 4.021128
# Epoch: 19 	Training Loss: 3.852641 	Validation Loss: 3.185136
# Epoch: 20 	Training Loss: 3.718309 	Validation Loss: 3.204250
# Epoch: 21 	Training Loss: 3.679301 	Validation Loss: 3.167930
# Epoch: 22 	Training Loss: 3.666523 	Validation Loss: 3.534571
# Epoch: 23 	Training Loss: 4.121616 	Validation Loss: 3.169758
# Epoch: 24 	Training Loss: 3.645769 	Validation Loss: 3.341037
# Epoch: 25 	Training Loss: 3.762665 	Validation Loss: 3.246393
# Epoch: 26 	Training Loss: 3.724442 	Validation Loss: 3.098769
# Validation loss decreased (3.164662 --> 3.098769).  Saving model ...
# Epoch: 27 	Training Loss: 3.618759 	Validation Loss: 3.539985
# Epoch: 28 	Training Loss: 3.708632 	Validation Loss: 3.301846
# Epoch: 29 	Training Loss: 3.790980 	Validation Loss: 3.235939
# Epoch: 30 	Training Loss: 3.849355 	Validation Loss: 3.240656
# Epoch: 31 	Training Loss: 4.034137 	Validation Loss: 3.331089
# Epoch: 32 	Training Loss: 3.778155 	Validation Loss: 3.711215
# Epoch: 33 	Training Loss: 3.726057 	Validation Loss: 3.680422
# Epoch: 34 	Training Loss: 3.589206 	Validation Loss: 3.054963
# Validation loss decreased (3.098769 --> 3.054963).  Saving model ...
# Epoch: 35 	Training Loss: 3.476288 	Validation Loss: 3.060972
# Epoch: 36 	Training Loss: 3.492039 	Validation Loss: 3.342827
# Epoch: 37 	Training Loss: 3.679111 	Validation Loss: 3.019725
# Validation loss decreased (3.054963 --> 3.019725).  Saving model ...
# Epoch: 38 	Training Loss: 3.476756 	Validation Loss: 3.038846
# Epoch: 39 	Training Loss: 3.582898 	Validation Loss: 3.194990
# Epoch: 40 	Training Loss: 3.643935 	Validation Loss: 3.046716
# Epoch: 41 	Training Loss: 3.482890 	Validation Loss: 3.006861
# Validation loss decreased (3.019725 --> 3.006861).  Saving model ...
# Epoch: 42 	Training Loss: 3.566028 	Validation Loss: 3.465616
# Epoch: 43 	Training Loss: 3.458231 	Validation Loss: 2.970377
# Validation loss decreased (3.006861 --> 2.970377).  Saving model ...
# Epoch: 44 	Training Loss: 3.507782 	Validation Loss: 3.029280
# Epoch: 45 	Training Loss: 3.401427 	Validation Loss: 2.960810
# Validation loss decreased (2.970377 --> 2.960810).  Saving model ...
# Epoch: 46 	Training Loss: 3.525607 	Validation Loss: 3.013740
# Epoch: 47 	Training Loss: 3.424421 	Validation Loss: 3.421814
# Epoch: 48 	Training Loss: 3.551013 	Validation Loss: 2.935662
# Validation loss decreased (2.960810 --> 2.935662).  Saving model ...
# Epoch: 49 	Training Loss: 3.589299 	Validation Loss: 3.967530
# Epoch: 50 	Training Loss: 3.529812 	Validation Loss: 3.052519
# ([24.5933332484598,
#   7.498122879374413,
#   5.019912861587145,
#   4.158746476357492,
#   4.053043854654131,
#   4.188014794450779,
#   4.15780432917348,
#   3.913416043469714,
#   3.8633794524685903,
#   3.8583249238241364,
#   3.8566556600310293,
#   3.826136529054049,
#   3.8381322858976064,
#   3.944439344801887,
#   3.7549120725878287,
#   3.7256081992929557,
#   3.701744287613574,
#   3.735457533925304,
#   3.8526411130458964,
#   3.7183088710409273,
#   3.6793008340743145,
#   3.6665231116991484,
#   4.121615524975869,
#   3.6457694436057686,
#   3.762664838546124,
#   3.72444213798633,
#   3.6187588192161426,
#   3.7086324556779102,
#   3.7909797714113096,
#   3.8493549612658233,
#   4.03413715320751,
#   3.7781554942418576,
#   3.726056716597506,
#   3.5892063315263325,
#   3.4762877495429008,
#   3.492038938272717,
#   3.679111133634283,
#   3.476756486785264,
#   3.5828977512310294,
#   3.6439350386886997,
#   3.4828900669089076,
#   3.566027692107787,
#   3.4582314970422114,
#   3.507782052798472,
#   3.401427108306981,
#   3.5256069552594056,
#   3.424421438748598,
#   3.5510132178099725,
#   3.5892985105224664,
#   3.5298117211351805],
#  [8.722365358018402,
#   5.215321976731081,
#   3.783718988104289,
#   3.515807214691121,
#   3.730839324328394,
#   3.771711872882437,
#   3.4873884923660268,
#   3.4054630132168024,
#   3.268290971800646,
#   3.582804164962837,
#   3.5074383162279448,
#   3.24298545107827,
#   3.6543769063758473,
#   3.274384217366672,
#   3.25722260833776,
#   3.243712289115037,
#   3.1646620257591285,
#   4.021127895026844,
#   3.1851359291998347,
#   3.2042498305466034,
#   3.1679297922575005,
#   3.5345705274429036,
#   3.1697581150143868,
#   3.3410367637208167,
#   3.2463928830975814,
#   3.0987694792226157,
#   3.5399846414605194,
#   3.301845730217452,
#   3.2359387081596744,
#   3.2406558767363935,
#   3.331089496607049,
#   3.7112145754553016,
#   3.680421913489231,
#   3.0549628628313688,
#   3.0609719907997586,
#   3.342826740454904,
#   3.019724712060875,
#   3.0388464842080407,
#   3.194989963763617,
#   3.046715621381487,
#   3.00686063209613,
#   3.465616069360518,
#   2.9703768691921275,
#   3.0292800984410295,
#   2.9608103036927527,
#   3.013739614349062,
#   3.421813590523038,
#   2.935662378063395,
#   3.9675297583092166,
#   3.0525194931479445])

# %%
def predict(data_loader, model):
    '''
    Predict keypoints
    Args:
        data_loader (DataLoader): DataLoader for Dataset
        model (nn.Module): trained model for prediction.
    Return:
        predictions (array-like): keypoints in float (no. of images x keypoints).
    '''
    
    model.eval() # prep model for evaluation

    with torch.no_grad():
        for i, batch in enumerate(data_loader):
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(batch['image'].to(device)).cpu().numpy()
            if i == 0:
                predictions = output
            else:
                predictions = np.vstack((predictions, output))
    
    return predictions

def view_pred_df(columns, test_df, predictions, image_ids=range(1,6)):
    '''
    Display predicted keypoints
    Args:
        columns (array-like): column names
        test_df (DataFrame): dataframe with ImageId and Image columns
        predictions (array-like): keypoints in float (no. of images x keypoints)
        image_id (array-like): list or range of ImageIds begin at 1
    '''
    pred_df = pd.DataFrame(predictions, columns=columns)
    pred_df = pd.concat([pred_df, test_df], axis=1)
    pred_df = pred_df.set_index('ImageId')
    show_images(pred_df, image_ids)  # ImageId as index begin at 1

# %%
model.load_state_dict(torch.load('aug_cnn.pt'))
predictions = predict(test_loader, model)
columns = train_df.drop('Image', axis=1).columns
view_pred_df(columns, test_df, predictions)
